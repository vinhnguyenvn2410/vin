# %% [markdown]
# # Why this project?
# I recently had the opportunity to read a new book written by my childhood hero and inspiration: Sir Alexander Ferguson CBE. The book was co-written by the legendary investor Sir Michael Jonathan Moritz KBE from Sequoia Capital, the firm which has invested in many of the tech companies that i'm applying for jobs! The book delved into the amazing time of Sir Alex Ferguson and how he turned Manchester United into a top team and brand around the globe.
# So, why this project? I love soccer. Also, the book mentioned a lot about how Sir Alex Ferguson embraced a lot of the new technology while maintaining his strong belief in disciplines and team chemistry. This lead to many variables that I haven't thought about before. Hence, I wanted to take a look at how teams in the League are performing based on some of the variables from the book.
# Last but not least, I believe this is a good way for me to practice my understandings of a dataset as well as thinking about data in the modern business world.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df10 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E10.csv', parse_dates=True, header=0)
df11 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E11.csv', parse_dates=True, header=0)
df12 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E12.csv', parse_dates=True, header=0)
df13 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E13.csv', parse_dates=True, header=0)
df14 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E14.csv', parse_dates=True, header=0)
df15 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E15.csv', parse_dates=True, header=0)
df16 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E16.csv', parse_dates=True, header=0)
df17 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E17.csv', parse_dates=True, header=0)
df18 = pd.read_csv('C:/Users/vinhn/Desktop/epl_matches/E18.csv', parse_dates=True, header=0)

# %% [markdown]
# # What do we have in our dataset?
# Div = League Division
# Date = Match Date (dd/mm/yy)
# HomeTeam = Home Team
# AwayTeam = Away Team
# FTHG and HG = Full Time Home Team Goals
# FTAG and AG = Full Time Away Team Goals
# FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
# Match Statistics (where available)
# Referee = Match Referee
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# AST = Away Team Shots on Target
# HC = Home Team Corners
# AC = Away Team Corners
# HF = Home Team Fouls Committed
# AF = Away Team Fouls Committed
# HY = Home Team Yellow Cards
# AY = Away Team Yellow Cards
# HR = Home Team Red Cards
# AR = Away Team Red Cards
# HBP = Home Team Bookings Points (10 = yellow, 25 = red)
# ABP = Away Team Bookings Points (10 = yellow, 25 = red)

# %%
#merging the tables
dataframes = [df10,df11,df12,df13,df14,df15,df16,df17,df18]
df = pd.concat(dataframes, ignore_index=True, sort=False,axis=0)

# %% [markdown]
# Although we would like to have as much data as possible, some of the columns aren't relevant to this analysis.

# %%
df.drop(df.columns[23:], axis=1,inplace=True)

# %%
df.head(50)
# Out:
#    Div      Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0   E0  14/08/10  Aston Villa     West Ham   3.0   0.0   H   2.0   0.0   H
# 1   E0  14/08/10    Blackburn      Everton   1.0   0.0   H   1.0   0.0   H
# 2   E0  14/08/10       Bolton       Fulham   0.0   0.0   D   0.0   0.0   D
# 3   E0  14/08/10      Chelsea    West Brom   6.0   0.0   H   2.0   0.0   H
# 4   E0  14/08/10   Sunderland   Birmingham   2.0   2.0   D   1.0   0.0   H
# 5   E0  14/08/10    Tottenham     Man City   0.0   0.0   D   0.0   0.0   D
# 6   E0  14/08/10        Wigan    Blackpool   0.0   4.0   A   0.0   3.0   A
# 7   E0  14/08/10       Wolves        Stoke   2.0   1.0   H   2.0   0.0   H
# 8   E0  15/08/10    Liverpool      Arsenal   1.0   1.0   D   0.0   0.0   D
# 9   E0  16/08/10   Man United    Newcastle   3.0   0.0   H   2.0   0.0   H
# 10  E0  21/08/10      Arsenal    Blackpool   6.0   0.0   H   3.0   0.0   H
# 11  E0  21/08/10   Birmingham    Blackburn   2.0   1.0   H   0.0   0.0   D
# 12  E0  21/08/10      Everton       Wolves   1.0   1.0   D   1.0   0.0   H
# 13  E0  21/08/10        Stoke    Tottenham   1.0   2.0   A   1.0   2.0   A
# 14  E0  21/08/10    West Brom   Sunderland   1.0   0.0   H   0.0   0.0   D
# 15  E0  21/08/10     West Ham       Bolton   1.0   3.0   A   0.0   0.0   D
# 16  E0  21/08/10        Wigan      Chelsea   0.0   6.0   A   0.0   1.0   A
# 17  E0  22/08/10       Fulham   Man United   2.0   2.0   D   0.0   1.0   A
# 18  E0  22/08/10    Newcastle  Aston Villa   6.0   0.0   H   3.0   0.0   H
# 19  E0  23/08/10     Man City    Liverpool   3.0   0.0   H   1.0   0.0   H
# 20  E0  28/08/10    Blackburn      Arsenal   1.0   2.0   A   1.0   1.0   D
# 21  E0  28/08/10    Blackpool       Fulham   2.0   2.0   D   0.0   1.0   A
# 22  E0  28/08/10      Chelsea        Stoke   2.0   0.0   H   1.0   0.0   H
# 23  E0  28/08/10   Man United     West Ham   3.0   0.0   H   1.0   0.0   H
# 24  E0  28/08/10    Tottenham        Wigan   0.0   1.0   A   0.0   0.0   D
# 25  E0  28/08/10       Wolves    Newcastle   1.0   1.0   D   1.0   0.0   H
# 26  E0  29/08/10  Aston Villa      Everton   1.0   0.0   H   1.0   0.0   H
# 27  E0  29/08/10       Bolton   Birmingham   2.0   2.0   D   0.0   1.0   A
# 28  E0  29/08/10    Liverpool    West Brom   1.0   0.0   H   0.0   0.0   D
# 29  E0  29/08/10   Sunderland     Man City   1.0   0.0   H   0.0   0.0   D
# 30  E0  11/09/10      Arsenal       Bolton   4.0   1.0   H   1.0   1.0   D
# 31  E0  11/09/10      Everton   Man United   3.0   3.0   D   1.0   1.0   D
# 32  E0  11/09/10       Fulham       Wolves   2.0   1.0   H   0.0   1.0   A
# 33  E0  11/09/10     Man City    Blackburn   1.0   1.0   D   0.0   1.0   A
# 34  E0  11/09/10    Newcastle    Blackpool   0.0   2.0   A   0.0   1.0   A
# 35  E0  11/09/10    West Brom    Tottenham   1.0   1.0   D   1.0   1.0   D
# 36  E0  11/09/10     West Ham      Chelsea   1.0   3.0   A   0.0   2.0   A
# 37  E0  11/09/10        Wigan   Sunderland   1.0   1.0   D   0.0   0.0   D
# 38  E0  12/09/10   Birmingham    Liverpool   0.0   0.0   D   0.0   0.0   D
# 39  E0  13/09/10        Stoke  Aston Villa   2.0   1.0   H   0.0   1.0   A
# 40  E0  18/09/10  Aston Villa       Bolton   1.0   1.0   D   1.0   1.0   D
# 41  E0  18/09/10    Blackburn       Fulham   1.0   1.0   D   1.0   0.0   H
# 42  E0  18/09/10      Everton    Newcastle   0.0   1.0   A   0.0   1.0   A
# 43  E0  18/09/10        Stoke     West Ham   1.0   1.0   D   0.0   1.0   A
# 44  E0  18/09/10   Sunderland      Arsenal   1.0   1.0   D   0.0   1.0   A
# 45  E0  18/09/10    Tottenham       Wolves   3.0   1.0   H   0.0   1.0   A
# 46  E0  18/09/10    West Brom   Birmingham   3.0   1.0   H   0.0   1.0   A
# 47  E0  19/09/10      Chelsea    Blackpool   4.0   0.0   H   4.0   0.0   H
# 48  E0  19/09/10   Man United    Liverpool   3.0   2.0   H   1.0   0.0   H
# 49  E0  19/09/10        Wigan     Man City   0.0   2.0   A   0.0   1.0   A
#
#    ...    HST   AST    HF    AF    HC    AC   HY   AY   HR   AR
# 0  ...   11.0   2.0  15.0  15.0  16.0   7.0  1.0  2.0  0.0  0.0
# 1  ...    2.0  12.0  19.0  14.0   1.0   3.0  2.0  1.0  0.0  0.0
# 2  ...    9.0   7.0  12.0  13.0   4.0   8.0  1.0  3.0  0.0  0.0
# 3  ...   13.0   4.0  10.0  10.0   3.0   1.0  1.0  0.0  0.0  0.0
# 4  ...    2.0   7.0  13.0  10.0   3.0   6.0  3.0  3.0  1.0  0.0
# 5  ...   18.0   7.0  13.0  16.0  10.0   3.0  0.0  2.0  0.0  0.0
# 6  ...    6.0   7.0   8.0  11.0   6.0   4.0  1.0  1.0  0.0  0.0
# 7  ...    7.0   6.0  17.0  13.0   5.0   5.0  0.0  2.0  0.0  0.0
# 8  ...    4.0   7.0  13.0  15.0   9.0  11.0  1.0  3.0  1.0  1.0
# 9  ...   10.0   3.0   9.0   5.0   5.0   3.0  2.0  2.0  0.0  0.0
# 10 ...   16.0   1.0   9.0   3.0   8.0   2.0  0.0  0.0  0.0  1.0
# 11 ...    7.0   2.0  13.0  14.0   4.0  12.0  2.0  3.0  0.0  0.0
# 12 ...    6.0   4.0  18.0  15.0   3.0   3.0  1.0  2.0  0.0  0.0
# 13 ...   10.0   6.0  15.0   4.0   6.0   2.0  3.0  1.0  0.0  0.0
# 14 ...    5.0   4.0  16.0  12.0   4.0   6.0  2.0  2.0  0.0  0.0
# 15 ...   10.0   8.0  11.0  18.0   8.0   5.0  2.0  4.0  0.0  0.0
# 16 ...   12.0   8.0  12.0   7.0   0.0   0.0  1.0  2.0  0.0  0.0
# 17 ...    8.0   7.0   7.0   6.0   5.0  11.0  2.0  2.0  0.0  0.0
# 18 ...   14.0   1.0  15.0  12.0  10.0   2.0  3.0  1.0  0.0  0.0
# 19 ...    3.0   7.0  13.0  12.0   5.0   4.0  1.0  1.0  0.0  0.0
# 20 ...    7.0   9.0   9.0   7.0   4.0   8.0  1.0  0.0  0.0  0.0
# 21 ...    5.0   7.0  13.0  16.0   4.0   5.0  1.0  0.0  0.0  0.0
# 22 ...    6.0   3.0   5.0  10.0   6.0   1.0  0.0  2.0  0.0  0.0
# 23 ...   11.0   2.0   6.0  11.0   9.0   3.0  1.0  2.0  0.0  0.0
# 24 ...    7.0   5.0  10.0  11.0  16.0   7.0  3.0  2.0  0.0  0.0
# 25 ...    2.0   6.0  20.0  17.0   5.0   3.0  7.0  4.0  0.0  0.0
# 26 ...    6.0   9.0  19.0  10.0   4.0  16.0  4.0  0.0  0.0  0.0
# 27 ...    8.0   5.0  19.0  17.0   6.0   1.0  2.0  3.0  1.0  0.0
# 28 ...    7.0   5.0   9.0   8.0   7.0   6.0  0.0  0.0  0.0  1.0
# 29 ...    4.0   7.0   5.0   9.0   3.0   7.0  0.0  3.0  0.0  0.0
# 30 ...   14.0   6.0  11.0  11.0   9.0   6.0  2.0  2.0  0.0  1.0
# 31 ...   14.0   8.0  11.0  18.0   7.0   5.0  1.0  1.0  0.0  0.0
# 32 ...    6.0   2.0   9.0  17.0   6.0   6.0  3.0  6.0  0.0  1.0
# 33 ...   14.0   2.0  12.0  10.0  14.0   2.0  2.0  1.0  0.0  0.0
# 34 ...   13.0   4.0  15.0  14.0   3.0   2.0  2.0  3.0  0.0  0.0
# 35 ...    8.0   9.0  12.0   9.0   9.0   4.0  2.0  1.0  0.0  0.0
# 36 ...    7.0   9.0  13.0  10.0   1.0   5.0  2.0  2.0  0.0  0.0
# 37 ...    4.0   2.0  19.0  11.0   5.0   1.0  4.0  2.0  0.0  1.0
# 38 ...    3.0   8.0   8.0   9.0   4.0   3.0  1.0  0.0  0.0  0.0
# 39 ...   12.0   6.0  11.0  14.0   8.0   7.0  1.0  2.0  0.0  0.0
# 40 ...    6.0   7.0  15.0   8.0   8.0   4.0  1.0  2.0  0.0  0.0
# 41 ...    5.0   4.0  15.0  10.0   3.0   3.0  0.0  1.0  0.0  0.0
# 42 ...    3.0   4.0  15.0  21.0   3.0   6.0  2.0  3.0  0.0  0.0
# 43 ...    3.0   6.0  14.0   8.0   6.0   3.0  3.0  2.0  0.0  0.0
# 44 ...    5.0   7.0  11.0  13.0  11.0   3.0  2.0  2.0  0.0  1.0
# 45 ...   11.0   2.0   7.0  11.0   5.0   4.0  3.0  3.0  0.0  0.0
# 46 ...   10.0   3.0  11.0   8.0   5.0   0.0  1.0  1.0  0.0  0.0
# 47 ...   15.0   4.0   7.0   4.0   9.0   6.0  1.0  2.0  0.0  0.0
# 48 ...    7.0   1.0  15.0  10.0   6.0   1.0  4.0  1.0  0.0  0.0
# 49 ...    3.0   5.0  10.0  14.0   3.0   1.0  1.0  2.0  0.0  0.0
#
# [50 rows x 23 columns]

# %%
len(df)
# Out:
# 3241

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %% [markdown]
# # Exploratory analysis and calculating insightful variables

# %% [markdown]
# Quick look at the champions during the data period.
# I believe this can help us understand how these champions performed and quickly spot out some of the reasons why
# they are the champions of one of the most competitive and exciting soccer leagues in the world!

# %%
champions = [{'Team': 'ManUnited','Cup': 2},
             {'Team':'ManCity','Cup':3},
             {'Team':'Chelsea','Cup':2},
             {'Team':'LeicesterCity','Cup':1}]
championsdf = pd.DataFrame(champions)

# %%
championsplot = sns.barplot(data = championsdf, x = 'Team', y ='Cup', palette='bright')

# %% [markdown]
# A team wins 3 points for a win. New column Point_at_home indicates points the home team won during the match.

# %%
type(df.at[0,'FTHG']) 
df['Point_at_home'] = np.where(df['FTHG'] > df['FTAG'], 3, 
        np.where(df['FTHG'] == df['FTAG'], 1, 0))

# %%
df.tail(10)
# Out:
#      Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 3231  E0  29/12/2018        Brighton       Everton   1.0   0.0   H   0.0
# 3232  E0  29/12/2018          Fulham  Huddersfield   1.0   0.0   H   0.0
# 3233  E0  29/12/2018       Leicester       Cardiff   0.0   1.0   A   0.0
# 3234  E0  29/12/2018       Liverpool       Arsenal   5.0   1.0   H   4.0
# 3235  E0  29/12/2018       Tottenham        Wolves   1.0   3.0   A   1.0
# 3236  E0  29/12/2018         Watford     Newcastle   1.0   1.0   D   0.0
# 3237  E0  30/12/2018         Burnley      West Ham   2.0   0.0   H   2.0
# 3238  E0  30/12/2018  Crystal Palace       Chelsea   0.0   1.0   A   0.0
# 3239  E0  30/12/2018      Man United   Bournemouth   4.0   1.0   H   3.0
# 3240  E0  30/12/2018     Southampton      Man City   1.0   3.0   A   1.0
#
#       HTAG HTR      ...        AST    HF    AF    HC   AC   HY   AY   HR   AR  \
# 3231   0.0   D      ...        4.0  10.0  11.0   6.0  6.0  0.0  2.0  0.0  0.0
# 3232   0.0   D      ...        5.0  12.0  10.0   4.0  3.0  3.0  1.0  0.0  0.0
# 3233   0.0   D      ...        3.0  14.0  16.0  10.0  4.0  0.0  2.0  0.0  0.0
# 3234   1.0   H      ...        2.0   8.0  13.0   5.0  3.0  1.0  2.0  0.0  0.0
# 3235   0.0   H      ...        4.0   7.0   7.0   6.0  7.0  3.0  2.0  0.0  0.0
# 3236   1.0   A      ...        2.0  17.0  16.0   3.0  6.0  1.0  2.0  0.0  0.0
# 3237   0.0   H      ...        4.0  15.0  11.0   5.0  5.0  1.0  4.0  0.0  0.0
# 3238   0.0   D      ...        4.0  11.0   8.0   3.0  4.0  0.0  1.0  0.0  0.0
# 3239   1.0   H      ...        3.0  10.0   7.0   4.0  5.0  2.0  0.0  1.0  0.0
# 3240   3.0   A      ...        6.0  11.0  10.0   3.0  8.0  2.0  3.0  1.0  0.0
#
#       Point_at_home
# 3231              3
# 3232              3
# 3233              0
# 3234              3
# 3235              0
# 3236              1
# 3237              3
# 3238              0
# 3239              3
# 3240              0
#
# [10 rows x 24 columns]

# %% [markdown]
# Aggregating some of the data to have a better look at some of the insightful variables mentioned

# %%
hst = df.groupby(by = 'HomeTeam', as_index = False).agg({'HST': sum,'FTHG':sum,'Point_at_home':sum,'HS':sum,'HF':sum,'HR':sum,'HY':sum,'AS':sum,'FTHG':sum,'FTAG':sum})
hst['HS-AS'] =hst['HS'] - hst['AS'] 
hst['Conversion_rate_Shot_on_target_to_goals'] = (hst.FTHG/ hst.HST)
hst['Card_to_Foul_ratio'] = (hst.HR + hst.HY) / hst.HF
hst['Cards'] = hst.HR + hst.HY

# %%
hst.sort_values('Card_to_Foul_ratio', ascending=True)
# Out:
#           HomeTeam     HST   FTHG  Point_at_home      HS      HF    HR     HY  \
# 4        Blackpool   134.0   30.0             20   253.0   216.0   0.0   22.0
# 17       Liverpool  1222.0  327.0            328  2928.0  1597.0   6.0  181.0
# 5           Bolton   316.0   57.0             51   513.0   458.0   6.0   52.0
# 16       Leicester   377.0  131.0            143  1149.0   892.0   7.0  108.0
# 24         Reading    85.0   23.0             20   161.0   169.0   1.0   21.0
# 19      Man United  1145.0  328.0            367  2552.0  1759.0   7.0  230.0
# 11  Crystal Palace   444.0  116.0            124  1358.0  1227.0   4.0  162.0
# 2       Birmingham    77.0   19.0             26   182.0   192.0   2.0   24.0
# 25     Southampton   653.0  182.0            179  1819.0  1330.0  11.0  171.0
# 33           Wigan   425.0   70.0             63   747.0   672.0   2.0   90.0
# 12         Everton   991.0  280.0            297  2340.0  1725.0   9.0  231.0
# 15            Hull   220.0   67.0             73   697.0   652.0   6.0   85.0
# 10         Chelsea  1220.0  336.0            355  2825.0  1675.0  11.0  225.0
# 29       Tottenham  1271.0  299.0            335  2832.0  1601.0   5.0  221.0
# 14    Huddersfield    86.0   20.0             28   318.0   281.0   4.0   36.0
# 3        Blackburn   249.0   48.0             47   491.0   456.0   2.0   63.0
# 13          Fulham   625.0  130.0            120  1227.0   868.0   5.0  120.0
# 18        Man City  1266.0  417.0            395  2903.0  1663.0  11.0  232.0
# 26           Stoke   678.0  202.0            235  1830.0  1727.0   9.0  247.0
# 31       West Brom   802.0  199.0            198  1953.0  1616.0   7.0  234.0
# 0          Arsenal  1229.0  340.0            355  2711.0  1645.0  12.0  236.0
# 28         Swansea   678.0  179.0            190  1647.0  1280.0   6.0  188.0
# 34          Wolves   289.0   61.0             54   574.0   501.0   3.0   73.0
# 21       Newcastle   810.0  203.0            208  1969.0  1565.0   9.0  229.0
# 22         Norwich   409.0   96.0            105   968.0   769.0   3.0  114.0
# 32        West Ham   728.0  199.0            207  1945.0  1475.0   8.0  223.0
# 23             QPR   356.0   60.0             63   843.0   602.0   9.0   87.0
# 8          Burnley   237.0   68.0             88   757.0   694.0   0.0  112.0
# 9          Cardiff   108.0   33.0             33   367.0   270.0   0.0   44.0
# 1      Aston Villa   559.0  123.0            123  1334.0  1225.0  11.0  190.0
# 27      Sunderland   650.0  147.0            153  1654.0  1421.0  10.0  224.0
# 6      Bournemouth   296.0  100.0             94   880.0   617.0   3.0  102.0
# 20   Middlesbrough    59.0   17.0             18   205.0   210.0   0.0   38.0
# 30         Watford   270.0   88.0             95   851.0   824.0   7.0  145.0
# 7         Brighton   102.0   39.0             47   309.0   322.0   2.0   58.0
#
#         AS   FTAG   HS-AS  Conversion_rate_Shot_on_target_to_goals  \
# 4    260.0   37.0    -7.0                                 0.223881
# 17  1392.0  137.0  1536.0                                 0.267594
# 5    494.0   63.0    19.0                                 0.180380
# 16  1041.0   97.0   108.0                                 0.347480
# 24   286.0   33.0  -125.0                                 0.270588
# 19  1528.0  129.0  1024.0                                 0.286463
# 11  1248.0  134.0   110.0                                 0.261261
# 2    259.0   22.0   -77.0                                 0.246753
# 25  1279.0  146.0   540.0                                 0.278714
# 33   611.0  100.0   136.0                                 0.164706
# 12  1785.0  178.0   555.0                                 0.282543
# 15   773.0   80.0   -76.0                                 0.304545
# 10  1581.0  144.0  1244.0                                 0.275410
# 29  1569.0  150.0  1263.0                                 0.235248
# 14   295.0   39.0    23.0                                 0.232558
# 3    491.0   49.0     0.0                                 0.192771
# 13  1114.0  136.0   113.0                                 0.208000
# 18  1280.0  127.0  1623.0                                 0.329384
# 26  1832.0  177.0    -2.0                                 0.297935
# 31  1835.0  207.0   118.0                                 0.248130
# 0   1487.0  136.0  1224.0                                 0.276648
# 28  1612.0  170.0    35.0                                 0.264012
# 34   651.0   86.0   -77.0                                 0.211073
# 21  1620.0  186.0   349.0                                 0.250617
# 22   936.0   98.0    32.0                                 0.234719
# 32  1865.0  196.0    80.0                                 0.273352
# 23   764.0   77.0    79.0                                 0.168539
# 8    974.0   78.0  -217.0                                 0.286920
# 9    444.0   55.0   -77.0                                 0.305556
# 1   1312.0  161.0    22.0                                 0.220036
# 27  1763.0  171.0  -109.0                                 0.226154
# 6    821.0  107.0    59.0                                 0.337838
# 20   235.0   23.0   -30.0                                 0.288136
# 30   767.0   97.0    84.0                                 0.325926
# 7    376.0   36.0   -67.0                                 0.382353
#
#     Card_to_Foul_ratio  Cards
# 4             0.101852   22.0
# 17            0.117095  187.0
# 5             0.126638   58.0
# 16            0.128924  115.0
# 24            0.130178   22.0
# 19            0.134736  237.0
# 11            0.135289  166.0
# 2             0.135417   26.0
# 25            0.136842  182.0
# 33            0.136905   92.0
# 12            0.139130  240.0
# 15            0.139571   91.0
# 10            0.140896  236.0
# 29            0.141162  226.0
# 14            0.142349   40.0
# 3             0.142544   65.0
# 13            0.144009  125.0
# 18            0.146121  243.0
# 26            0.148234  256.0
# 31            0.149134  241.0
# 0             0.150760  248.0
# 28            0.151562  194.0
# 34            0.151697   76.0
# 21            0.152077  238.0
# 22            0.152146  117.0
# 32            0.156610  231.0
# 23            0.159468   96.0
# 8             0.161383  112.0
# 9             0.162963   44.0
# 1             0.164082  201.0
# 27            0.164673  234.0
# 6             0.170178  105.0
# 20            0.180952   38.0
# 30            0.184466  152.0
# 7             0.186335   60.0

# %% [markdown]
# Distribution of Conversion rate. A lot of teams converged around 26.75% conversion.

# %%
print('Mean: ',hst['Conversion_rate_Shot_on_target_to_goals'].mean(),', ','Median: ',hst['Conversion_rate_Shot_on_target_to_goals'].median())
# Out:
# Mean:  0.2624634324537121 ,  Median:  0.26759410801963995

# %%
sns.distplot(hst.Conversion_rate_Shot_on_target_to_goals);

# %% [markdown]
# The chart below shows the distribution of number of shots taken by the home team. We could see the distribution around 800 shots
# taken by the hometeam over the years. However, some teams have been enjoying significant advantage at home by shooting almost
# 4000 times at home. However, we need to keep in mind there are teams who have been in the League longer and more consistent
# than others.

# %%
sns.distplot(hst.HS);

# %% [markdown]
# The plot below plots the distribution of the differences between Away team's number of shots vs Home team's number of shots.
# As we could see, the chart is right skewed and peaks around 0. This shows that although the majority of matches didn't
# have significant advantages (in terms of shots taken by Away and Home team), there's many matches that show cases the signficant
# positive differences between Hometeam's number of shots and awayteam's number of shots (demonstrated by the long right tail).

# %%
print('Mean: ',hst['HS-AS'].mean(),', ','Median: ',hst['HS-AS'].median())
#Mean much higher than median consistent with right-skewed and outliers.
# Out:
# Mean:  271.77142857142854 ,  Median:  59.0

# %%
sns.distplot(hst['HS-AS']);

# %% [markdown]
# Card to foul ratio: this helps us understand the number of fouls teams have to commit, on average to get a card.

# %%
sns.distplot(hst.Card_to_Foul_ratio);

# %% [markdown]
# You can see an obvious positive relationship between number of shots the home team made
# versus the points they would be getting at home.

# %%
sns.lmplot('HS','Point_at_home',hst,scatter=True,fit_reg =True);

# %% [markdown]
# However, looking at the conversion rate from shot on target to goals, the correlation isn't clear anymore.
# especially 1 team with the highest conversion rate achieved very low amount of points won at home.

# %%
sns.lmplot('Conversion_rate_Shot_on_target_to_goals','Point_at_home',hst,scatter=True);

# %% [markdown]
# This is 'funny': the more the team fouled (tackled against the rules)
# the more points that team got at home.
# the home fans loves it. Dirty, but effective.
# Top 1 for number of fouls is Man United (my fav team)
#
# A different intepretation: However, we should keep in mind that these are fouls called by the referee. Which means the team might have been treated poorly by the referee as well.

# %%
sns.lmplot('HF','Point_at_home',hst,scatter=True);

# %% [markdown]
# Card to foul (the ref gives them less cards for their number of fouls for some reason: underdog? bribe? who knows...)
# It seems like the correlation here isn't too crazy.

# %%
sns.lmplot('Card_to_Foul_ratio','Point_at_home',hst,scatter=True);

# %% [markdown]
# Although more cards might also mean you are playing more games, it shows within both of these charts the relationship between cards (serious fouls) and the number of goals (both home goals and away goals) scored by teams.

# %%
print('Correlation between Cards and Home goals: ',hst['Cards'].corr(hst['FTHG']))
print('Correlation between Cards and Away goals: ',hst['Cards'].corr(hst['FTAG']))
# Out:
# Correlation between Cards and Home goals:  0.8639504582033772
# Correlation between Cards and Away goals:  0.9245765784811862

# %%
sns.lmplot('Cards','FTHG',hst,scatter=True);

# %%
sns.lmplot('Cards','FTAG',hst,scatter=True);

# %% [markdown]
# # Demonstration of a terrible Pie chart: I also heard that pie charts are the worse :(

# %%
#pie chart home team goals
plt.axis('equal')
plt.pie(hst.FTHG,labels = hst.HomeTeam, radius = 3, autopct='%0.1f%%');

# %% [markdown]
# Below is the percentage of matches where result didn't change after half time.
# It would interesting to see which team has the best result after being down or draw at half time.
# In over 60% of the matches, the result at half time remains the same till the end.

# %%
#What percentage of the matches where the result didn't change after the half time?
df['half_and_final_same'] = np.where(df.HTR == df.FTR,1,0)
no_change_results= sum(df.half_and_final_same)/df.shape[0]
print(no_change_results)
# Out:
# 0.6059858068497377

# %% [markdown]
# If 60% of the result includes draws and a team being ahead, what's the prob that a team ahead at half time is going to stay ahead at full-time?

# %%
df['Draw_at_half'] = np.where(df.HTR =='D', 1,0)
draw_athalf = sum(df.Draw_at_half) / df.shape[0]
print(draw_athalf)
# Out:
# 0.41653810552298676

# %%
df['Draw_at_full'] = np.where(df.FTR =='D', 1,0)
draw_atfull = sum(df.Draw_at_full) / df.shape[0]
print(draw_atfull)
# Out:
# 0.2505399568034557

# %% [markdown]
# # Applying Bayes Theorem (naive case where we assume independent)
#
# I will have to double check and continuously work on my understanding of this section. As a newbie practioner, I'm still practicing these assumptions. I will admit i'm not entirely sure about this part:
#
# P(B|A) = (P(A|B) * P(B)) / P(A)
#
# Probability half time result = draw given that full time result was a draw
#
# We know p(A = draw at full time) =  draw_atfull= 0.2505
#
# We know p(B = draw at half time) = draw_athalf = 0.4165
#
# We need to calculate P(A|B) which is probability of a draw at fulltime given draw at half-time.

# %%
df['ab'] = np.where(np.logical_and(df.HTR == 'D', df.FTR == 'D'),1,0)
ab = sum(df.ab) / df.shape[0]
print(ab)
# Out:
# 0.15612465288491206

# %%
#P(B|A)
Prob_half_draw_given_full_draw = (ab*draw_athalf) /(draw_atfull)
print(Prob_half_draw_given_full_draw)
# Out:
# 0.2595668490081666

# %% [markdown]
# Below is the percentage of matches where the reversal is real (A team being down in the first half came back and won)
# This doesn't consider draws at the half.
# The result shows only 13.36% of the match where a team comeback from trailing at half time.

# %%
# What % of reversed result after the half? (draw counted as reversed as well)
df['reversed'] = np.where(np.logical_and(df.HTR != df.FTR, df.HTHG != df.HTAG),1,0)
reversed_afterhalf = sum(df.reversed) / df.shape[0]
print(reversed_afterhalf)
# Out:
# 0.1336007405121876

# %% [markdown]
# In the U.S., one of the complaints about soccer is the fact that the game doesn't have a lot of action aka scores/goals
# like other sports like Basketball, Football, Pingpong... Let's take a look at games that noone scores on both sides.
# The results shows only 7.68% of the games ended in a 0-0 tie. A bit of exaggeration going on here. However, looking above, we could see 40% of the games draw at half time... which is 45 minutes into the game. This is quite disappointing in my opinion as the soccer styles around the globe has been more defensive (no thanks to Mr. Mourinho).

# %%
# Americans like to say soccer tie with no goals too much. Let's check this out?
df['tie00'] = np.where(np.logical_and(df.FTHG == df.FTAG,df.FTHG==0 ),1,0)
tie00_percentage = sum(df.tie00) / df.shape[0]
print(tie00_percentage)
# Out:
# 0.07682813946312866

# %% [markdown]
# Suprisingly, the crowds in the EPL is infamous for their hostility and hooliganess. Yet, home teams only won ~45.5% of the games
# since 2010
# Potential question: statistical significant of being at home?

# %%
len(df[(df.FTR == 'H')]) / df.shape[0]
# Out:
# 0.455106448626967

# %% [markdown]
# Which team is the best at home?

# %%
df['Home_Win'] = np.where(df.FTR == 'H', 1,0)
home_win = df.groupby(by = 'HomeTeam', as_index=False).agg({'Home_Win': sum}).sort_values(by = 'Home_Win', ascending  = False).head(10)
print(home_win)
# Out:
#       HomeTeam  Home_Win
# 18    Man City       124
# 19  Man United       113
# 0      Arsenal       107
# 10     Chelsea       107
# 29   Tottenham       100
# 17   Liverpool        94
# 12     Everton        85
# 26       Stoke        64
# 21   Newcastle        58
# 32    West Ham        57

# %%
homewinplot = sns.barplot(data=home_win.head(10), x='HomeTeam', y = 'Home_Win')
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(by = 'HomeTeam').agg({'HS':sum,'AS':sum}).sort_values(by = 'AS', ascending = False)
# Out:
#                     HS      AS
# HomeTeam
# West Ham        1945.0  1865.0
# West Brom       1953.0  1835.0
# Stoke           1830.0  1832.0
# Everton         2340.0  1785.0
# Sunderland      1654.0  1763.0
# Newcastle       1969.0  1620.0
# Swansea         1647.0  1612.0
# Chelsea         2825.0  1581.0
# Tottenham       2832.0  1569.0
# Man United      2552.0  1528.0
# Arsenal         2711.0  1487.0
# Liverpool       2928.0  1392.0
# Aston Villa     1334.0  1312.0
# Man City        2903.0  1280.0
# Southampton     1819.0  1279.0
# Crystal Palace  1358.0  1248.0
# Fulham          1227.0  1114.0
# Leicester       1149.0  1041.0
# Burnley          757.0   974.0
# Norwich          968.0   936.0
# Bournemouth      880.0   821.0
# Hull             697.0   773.0
# Watford          851.0   767.0
# QPR              843.0   764.0
# Wolves           574.0   651.0
# Wigan            747.0   611.0
# Bolton           513.0   494.0
# Blackburn        491.0   491.0
# Cardiff          367.0   444.0
# Brighton         309.0   376.0
# Huddersfield     318.0   295.0
# Reading          161.0   286.0
# Blackpool        253.0   260.0
# Birmingham       182.0   259.0
# Middlesbrough    205.0   235.0

# %% [markdown]
# # II. Going into some away stats

# %% [markdown]
# Some teams shoots a lot at home but not so much away. As we've learned, teams which took more shots might indicates more points at home.
# How about shots and points away?
# Which team has the highest difference of shots away and at home?

# %%
df['Point_away'] = np.where(df.FTR =='A',3,np.where(df.FTR =='D',1,0))
away_shot = df.groupby(by = 'AwayTeam').agg({'AS':sum,'Point_away':sum}).sort_values(by = 'Point_away', ascending = False)
away_shot
# Out:
#                     AS  Point_away
# AwayTeam
# Man City        2448.0         299
# Chelsea         2283.0         280
# Tottenham       2292.0         279
# Man United      1921.0         276
# Arsenal         2127.0         257
# Liverpool       2289.0         254
# Everton         1855.0         179
# West Brom       1555.0         144
# Southampton     1487.0         138
# West Ham        1528.0         135
# Newcastle       1490.0         131
# Stoke           1410.0         130
# Swansea         1317.0         122
# Sunderland      1311.0         117
# Crystal Palace  1121.0         115
# Leicester        925.0          98
# Aston Villa     1111.0          97
# Fulham           819.0          70
# Bournemouth      725.0          64
# Watford          691.0          59
# Wigan            611.0          58
# Burnley          619.0          54
# Norwich          758.0          53
# Wolves           472.0          40
# Hull             553.0          33
# Bolton           432.0          31
# QPR              649.0          29
# Blackburn        309.0          27
# Blackpool        193.0          19
# Huddersfield     270.0          19
# Brighton         252.0          18
# Cardiff          278.0          15
# Birmingham       145.0          13
# Middlesbrough    144.0          10
# Reading          190.0           8

# %%
sns.lmplot('AS','Point_away', away_shot, scatter=True);

# %% [markdown]
# Most clubs cluster around the even 0 mark. However, the distribution is right-skewed which indicates some clubs have significant
# advantage at home in terms of shot taken. This could be due to the fans cheering, the field familiarity...

# %%
HS_AS= df.groupby(by = 'HomeTeam',as_index=False).agg({'HS':sum,'AS':sum}).sort_values(by = 'AS', ascending = False)
HS_AS['Home_Away_ShotDiff'] = HS_AS['HS'] -HS_AS['AS']
HS_AS_sorted = HS_AS.sort_values(by = 'Home_Away_ShotDiff', ascending = False)
HS_AS_sorted

sns.distplot(HS_AS_sorted.Home_Away_ShotDiff, kde=False, bins= 25);

# %% [markdown]
# Let's take a quick look at the referee.
# These men work relentlessly to keep the game far and organized. 1
# 1. Most game by each ref during that period? (assuming each ref only ref ONE match per day)

# %%
df.groupby(by = ['Referee','HomeTeam']).agg({'Date': 'nunique','Point_away': 'sum'}).sort_values(by ='Point_away', ascending = False).head(15)
# Out:
#                            Date  Point_away
# Referee       HomeTeam
# A Taylor      Stoke          14          26
# M Dean        West Brom      15          25
# N Swarbrick   Aston Villa    10          24
# M Jones       Sunderland     12          23
# M Atkinson    Sunderland     13          23
# J Moss        Swansea        12          23
# A Marriner    Newcastle      15          23
# L Probert     West Brom      10          23
# A Marriner    West Ham       13          22
# J Moss        Watford        10          22
# M Atkinson    Stoke          13          21
# A Marriner    Stoke          11          20
# M Clattenburg West Brom      12          20
# M Dean        Aston Villa    12          20
# J Moss        Everton        13          20

# %% [markdown]
# 2. Most combination between ref and home team? and Away team?

# %%
ref_hometeam = df.groupby(by = ['Referee','HomeTeam'], as_index=False).agg({'Date': 'nunique'}).sort_values(by ='Date', ascending = False)
ref_hometeam.head(15)
# Out:
#         Referee   HomeTeam  Date
# 330  M Atkinson  Newcastle    21
# 400      M Dean  Tottenham    20
# 2    A Marriner    Arsenal    18
# 390      M Dean   Man City    17
# 449     M Jones  Tottenham    16
# 472    M Oliver  Liverpool    15
# 257     L Mason    Chelsea    15
# 374      M Dean    Arsenal    15
# 467    M Oliver    Everton    15
# 402      M Dean  West Brom    15
# 326  M Atkinson  Liverpool    15
# 20   A Marriner  Newcastle    15
# 48     A Taylor  Liverpool    14
# 33     A Taylor    Arsenal    14
# 383      M Dean    Chelsea    14

# %%
sns.barplot(data=ref_hometeam,x = 'Referee', y= 'Date')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This actually keeps the meme alive since people have been mocking ManU for the claims that Mike Dean helps them win...
# Amazingly so, Mike Dean helped United beat Spurs (Ole Gunnar Solskjær broke club record).

# %%
df.groupby(by = ['Referee','AwayTeam'],).agg({'Date': 'nunique',}).sort_values(by ='Date', ascending = False).head(10)
# Out:
#                           Date
# Referee       AwayTeam
# M Dean        Man United    20
#               Chelsea       19
# A Marriner    Man City      18
# M Clattenburg Man City      17
# A Marriner    Liverpool     17
# M Atkinson    Man City      17
#               Chelsea       16
# A Marriner    Chelsea       16
# A Taylor      Liverpool     16
# M Atkinson    Liverpool     16

# %% [markdown]
# 3. Number of red cards/ and yellow cards by the ref.
# Mr. Atkinson stays true to his infamous generosity in terms of giving out cards.

# %%
df.groupby(by = ['Referee','HomeTeam']).agg({'HR':sum,'AR':sum}).sort_values(by = 'HR', ascending = False).head(15)
# Out:
#                              HR   AR
# Referee       HomeTeam
# A Marriner    Newcastle     4.0  0.0
# M Clattenburg QPR           3.0  0.0
#               Man United    3.0  0.0
# M Atkinson    Arsenal       3.0  2.0
# P Dowd        QPR           2.0  0.0
# L Mason       Aston Villa   2.0  1.0
# M Oliver      Stoke         2.0  1.0
# N Swarbrick   Aston Villa   2.0  0.0
# J Moss        Leicester     2.0  1.0
#               Arsenal       2.0  1.0
# P Dowd        Aston Villa   2.0  0.0
# M Oliver      Huddersfield  2.0  1.0
# C Pawson      Sunderland    2.0  0.0
#               Chelsea       2.0  0.0
# A Taylor      West Ham      2.0  1.0

# %% [markdown]
# 4. Refs' number of games and the distribution among them

# %%
ref_total = df.groupby(by = 'Referee').agg({'Referee': 'count'}).sort_values(by ='Referee', ascending = False)
ref_total.head(15)
# Out:
#                Referee
# Referee
# M Dean             247
# M Atkinson         236
# M Oliver           221
# A Marriner         213
# A Taylor           209
# L Mason            191
# J Moss             186
# K Friend           178
# M Clattenburg      175
# M Jones            170
# N Swarbrick        132
# P Dowd             130
# L Probert          129
# C Pawson           123
# H Webb             119

# %%
sns.distplot(ref_total.Referee)

# %% [markdown]
# As you can see, there are lots of interesting things a club could do to further enhance their results such as:
# 1. Take more shots
# 2. Tackle people more (aka fouling). This might lead to more injury time and more cards but the team should be taking care of their players. It would be interesting to have an experiment to find causal relationship between fouling more and scoring. Although we did conduct a correlation calculation and visualization of these two variables.
# 3. Referees do make a difference (Thanks Mike Dean for United win over Spurs!)
# 4. The result shows only 13.36% of the match where a team comeback from trailing at half time.
# 5. The results shows only 7.68% of the games ended in a 0-0 tie. A bit of exaggeration going on here. However, looking above, we could see 40% of the games draw at half time... which is 45 minutes into the game. This is quite disappointing in my opinion as the soccer styles around the globe has been more defensive (no thanks to Mr. Mourinho).
# 6. Given a full-time result was 0-0, there's a 26% chance the result was 0-0 at half time.
